# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np 
import datetime

# %%
df = pd.read_csv('exercise_data.csv', skiprows= 1)

# %%
df.head()
# Out:
#                                                     live_data_internal  \
# b7f14445-c550-6858-5035-d6218d47bf85.live_data_...                 0.0
# 887bc33d-65e7-b86d-8b07-ee96b1cce386.live_data_...                 0.0
# 40002c33-077c-ddfc-0a97-984bc9f52ec0.live_data_...                 0.0
# 1ce3631c-381c-2898-71c3-c09cc58c9df2.live_data_...                 0.0
# 6431c55f-eda2-7930-34ed-2c6770bdac11.live_data_...                 0.0
#
#                                                     mission_value  \
# b7f14445-c550-6858-5035-d6218d47bf85.live_data_...            NaN
# 887bc33d-65e7-b86d-8b07-ee96b1cce386.live_data_...            NaN
# 40002c33-077c-ddfc-0a97-984bc9f52ec0.live_data_...            NaN
# 1ce3631c-381c-2898-71c3-c09cc58c9df2.live_data_...            NaN
# 6431c55f-eda2-7930-34ed-2c6770bdac11.live_data_...            NaN
#
#                                                     subset_data  \
# b7f14445-c550-6858-5035-d6218d47bf85.live_data_...     0.491767
# ...

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#                                                index  live_data_internal  \
# 0  b7f14445-c550-6858-5035-d6218d47bf85.live_data...                 0.0
# 1  887bc33d-65e7-b86d-8b07-ee96b1cce386.live_data...                 0.0
# 2  40002c33-077c-ddfc-0a97-984bc9f52ec0.live_data...                 0.0
# 3  1ce3631c-381c-2898-71c3-c09cc58c9df2.live_data...                 0.0
# 4  6431c55f-eda2-7930-34ed-2c6770bdac11.live_data...                 0.0
#
#    mission_value  subset_data  total_calorie  completion_status  pace_info_id  \
# 0            NaN     0.491767              0                NaN           NaN
# 1            NaN   250.803000              0                NaN           NaN
# 2            NaN    53.300594              0                NaN           NaN
# 3            NaN   235.030750              0                NaN           NaN
# 4            NaN    53.556324              0                NaN           NaN
#
# ...

# %%
df.rename(columns = {'index' : 'live_data_internal'}, inplace = True)

# %%
df.head()
# Out:
#                                   live_data_internal  live_data_internal  \
# 0  b7f14445-c550-6858-5035-d6218d47bf85.live_data...                 0.0
# 1  887bc33d-65e7-b86d-8b07-ee96b1cce386.live_data...                 0.0
# 2  40002c33-077c-ddfc-0a97-984bc9f52ec0.live_data...                 0.0
# 3  1ce3631c-381c-2898-71c3-c09cc58c9df2.live_data...                 0.0
# 4  6431c55f-eda2-7930-34ed-2c6770bdac11.live_data...                 0.0
#
#    mission_value  subset_data  total_calorie  completion_status  pace_info_id  \
# 0            NaN     0.491767              0                NaN           NaN
# 1            NaN   250.803000              0                NaN           NaN
# 2            NaN    53.300594              0                NaN           NaN
# 3            NaN   235.030750              0                NaN           NaN
# 4            NaN    53.556324              0                NaN           NaN
#
# ...

# %%
df.shape
# Out:
# (415, 62)

# %%
# I need to get rid of the columns I do not need

# %%
df.columns
# Out:
# Index(['live_data_internal', 'live_data_internal', 'mission_value',
#        'subset_data', 'total_calorie', 'completion_status', 'pace_info_id',
#        'pace_live_data', 'sensing_status', 'source_type', 'mission_type',
#        'tracking_status', 'program_id', 'title', 'reward_status',
#        'heart_rate_sample_count', 'mission_extra_value', 'program_schedule_id',
#        'heart_rate_deviceuuid', 'location_data_internal',
#        'additional_internal', 'com.samsung.health.exercise.duration',
#        'com.samsung.health.exercise.additional',
#        'com.samsung.health.exercise.mean_caloricburn_rate',
#        'com.samsung.health.exercise.location_data',
#        'com.samsung.health.exercise.start_time',
#        'com.samsung.health.exercise.exercise_type',
#        'com.samsung.health.exercise.custom',
#        'com.samsung.health.exercise.max_altitude',
#        'com.samsung.health.exercise.incline_distance',
#        'com.samsung.health.exercise.mean_heart_rate',
# ...

# %%
# I should find out what 'reward_status is'

# what are the columns I do not need: 

# 'live_data_internal', 'mission_value', 'subset_data', 'completion_status', 'pace_info_id', 'pace_live_data', 'sensing_status',
# 'mission_type', 'tracking_status', 'program_id', 'title',
